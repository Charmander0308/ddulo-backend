# %%
'''
../data/past_average_congestion_with_platform.csv
파일을 읽어와 dataframe으로 로드
'''
import pandas as pd



df = pd.read_csv('../../data/past_average_congestion_with_platform.csv')

df
# Out:
#     subwayLine stationName  stationCode  updnLine  dow  hh  mm  \
# 0          2호선         삼성역          219         1  FRI  17   0
# 1          2호선         삼성역          219         1  FRI  17  10
# 2          2호선         삼성역          219         1  FRI  17  20
# 3          2호선         삼성역          219         1  FRI  17  30
# 4          2호선         삼성역          219         1  FRI  17  40
# ..         ...         ...          ...       ...  ...  ..  ..
# 751        7호선         신풍역          743         1  WED  19  10
# 752        7호선         신풍역          743         1  WED  19  20
# 753        7호선         신풍역          743         1  WED  19  30
# 754        7호선         신풍역          743         1  WED  19  40
# 755        7호선         신풍역          743         1  WED  19  50
#
#     prevStationName  prevStationCode  \
# 0            종합운동장역              218
# 1            종합운동장역              218
# 2            종합운동장역              218
# 3            종합운동장역              218
# ...

# %%
'''
stationName, dow, hh, mm 순으로 정렬
'''
df = df.sort_values(by=['stationName', 'dow', 'hh', 'mm'])
df
# Out:
#     subwayLine stationName  stationCode  updnLine  dow  hh  mm  \
# 378        7호선         대림역          744         1  FRI  17   0
# 379        7호선         대림역          744         1  FRI  17  10
# 380        7호선         대림역          744         1  FRI  17  20
# 381        7호선         대림역          744         1  FRI  17  30
# 382        7호선         대림역          744         1  FRI  17  40
# ..         ...         ...          ...       ...  ...  ..  ..
# 373        2호선         역삼역          221         1  WED  19  10
# 374        2호선         역삼역          221         1  WED  19  20
# 375        2호선         역삼역          221         1  WED  19  30
# 376        2호선         역삼역          221         1  WED  19  40
# 377        2호선         역삼역          221         1  WED  19  50
#
#     prevStationName  prevStationCode  \
# 378             신풍역              743
# 379             신풍역              743
# 380             신풍역              743
# 381             신풍역              743
# ...
